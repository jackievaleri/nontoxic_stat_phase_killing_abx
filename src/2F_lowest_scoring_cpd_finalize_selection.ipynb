# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import subprocess
import os

import rdkit
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import rdmolops
from rdkit import DataStructs
from rdkit.Chem import AllChem
from rdkit.ML.Cluster import Butina

# shut off warnings
from rdkit import RDLogger                                                                                                                                                               
RDLogger.DisableLog('rdApp.*')  

import matplotlib
from matplotlib import rc
font = {'size'   : 8}
matplotlib.rc('font', **font)

# change font
matplotlib.rcParams['font.sans-serif'] = "Arial"
matplotlib.rcParams['font.family'] = "sans-serif"

# %% [markdown]
# # Part 1: Read in data and get worst predicted killing compounds

# %%
res_folder = ''
df = pd.read_csv('../out/round3finalval08162021_broad_chunks_final_predictions_broad800k_08_20_2021.csv')
df = df.sort_values(by = 'hit_kill', ascending = True)
df = df.iloc[0:1000,:] # get worst 1000 to start

df['SMILES'] = df['smiles']
meta = pd.read_csv('../../beta_lactam/data/PublicStructures.txt', sep = '\t')
df = df.merge(meta, on = 'SMILES')

# use same functions as described in 2C.2_calculate_tanimoto_similarity_of_hits.ipynb
smis = list(df['SMILES'])
print("Computing tanimoto scores against abx...")
df = compute_tanimoto_against_abx(smis, df)
print("Computing tanimoto scores against training set...")
df = compute_tanimoto_against_training_set(smis, df)
df = df[df['tanimoto similarity to closest train set'] < 1]
df.to_csv('../out/round3finalval08162021_plots/worst_mols_broad800k_kill02_predicted_hits.csv', index = False)

# %%
# apply same threshold as earlier
simthresh = 0.9

df = pd.read_csv('../out/worst_mols_broad800k_model_predictions.csv')
df = df[df['tanimoto similarity to closest train set'] < simthresh]
df = df[df['tanimoto similarity to closest abx'] < simthresh]
df = df.iloc[0:300,:]

df.to_csv('../out/finalized_selected_worst_mols_broad800k_model_predictions.csv', index = False)
df
# Out:
#                                                 SMILES  \
# 0           COCc1ccc(s1)C(=O)N1CCC(CC1)(C(=O)O)n1cccn1
# 1                 CCOC(=O)C1CCN(CC1)C(=S)NC(=O)c1cccs1
# 2    CCN1CCCC1=O.CO[C@H]1CN(CCO)S(=O)(=O)c2ccccc21....
# 3                                  ONC(=O)c1ccc(s1)C#C
# 4                        CCNC(=S)NNC(=O)c1csc(c1)C(C)C
# ..                                                 ...
# 295   O=C(N1CCC[C@@H](C1)c1ccn[nH]1)c1ccc(cc1)Cn1cnnn1
# 296                      COC(=O)c1sccc1NC(=S)N(C)CCC#N
# 297  CCn1ncc(n1)NC(=O)c1ccc(s1)[C@H]1CCCN1Cc1[nH]cnc1C
# 298                 O=C(Cc1ccccc1)NNC(=S)NC(=O)c1cccs1
# 299  O=C1C=C(NC=N1)C1CCN(CC1)C(=O)c1ccc(s1)[C@H]1CCCO1
#
#      tanimoto similarity to closest train set  \
# 0                                    0.446043
# 1                                    0.375624
# 2                                    0.829735
# 3                                    0.279221
# 4                                    0.312549
# ..                                        ...
# 295                                  0.451419
# 296                                  0.482402
# 297                                  0.527582
# 298                                  0.353811
# 299                                  0.469472
#
#                               closest train set smiles  \
# 0    CC[C@@]12CCCN3CCc4c([C@H]13)n(c1ccccc41)[C@](O...
# 1              Clc1cccc2cc(sc12)C(=O)N[C@H]1CN2CCC1CC2
# 2    CC[C@H](C)[C@@H]1N[C@@H]2C=Cc3c(cc(nc3[C@H]2O)...
# 3             Cc1cc(sc1[C@@H](N)C(O)=O)C(O)=O |&1:6,r|
# 4                          ClC=C1Nc2sc3CCCCc3c2C(=O)N1
# ..                                                 ...
# 295  Fc1ccc(cc1)C(=O)N1CCC[C@@H](C1)c1nc(no1)-c1ccc...
# 296        CCCN[C@@H](C)C(=O)Nc1c(C)csc1C(=O)OC |&1:4|
# 297  CN1CCN(C)C(=O)[C@@H]1c1ccc(Nc2nc(cn(C)c2=O)-c2...
# 298                   Cc1[nH]c2ccccc2c1CCNC(=O)c1cccs1
# 299  Oc1ccc2C[C@H]3N(CC4CC4)CC[C@@]45[C@@H](Oc1c24)...
#
#                                 closest train set name  \
# 0                                            vincamine
# 1                                             EVP-6124
# 2                                         thiostrepton
# 3                                             3-MATIDA
# 4    2-(chloromethyl)-5,6,7,8-tetrahydro[1]benzothi...
# ..                                                 ...
# 295                                          ADX-47273
# 296                                          articaine
# 297                                           GDC-0834
# 298                                             CK-636
# 299                                N-benzylnaltrindole
#
#      tanimoto similarity to closest abx  \
# 0                              0.439402
# 1                              0.285604
# 2                              0.793291
# 3                              0.175266
# 4                              0.239979
# ..                                  ...
# 295                            0.386072
# 296                            0.304162
# 297                            0.512545
# 298                            0.260530
# 299                            0.457919
#
#                                     closest abx smiles closest abx name  \
# 0    CC1(C)S[C@@H]2[C@H](NC(=O)COc3ccccc3)C(=O)N2[C...  PENIMEPICYCLINE
# 1    CC(=O)C(=O)N[C@@H]1/C=C(C)/C=C/[C@@H](OC(=O)N2...     TERDECAMYCIN
# 2    CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(=O)c(c5o...        RIFALAZIL
# 3    CC(C)=CCC/C(C)=C/CC/C(C)=C/CN1C(=O)c2cccc(O)c2...   DIAZEPINOMICIN
# 4    Cc1c(N)nc([C@H](CC(N)=O)NC[C@H](N)C(N)=O)nc1C(...      TALISOMYCIN
# ..                                                 ...              ...
# 295        Cc1ccc2c(c1O)NC(O)C1CC(/C=C/C(N)=O)=CN1C2=O      ANTHRAMYCIN
# 296  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C)c(O)c4c(c3C2=O)C...        RIFABUTIN
# 297  Cc1c(N)nc([C@H](CC(N)=O)NC[C@H](N)C(N)=O)nc1C(...      TALISOMYCIN
# 298  N[C@@H](C(=O)N[C@@H]1C(=O)N2C(C(=O)O)=C(Cl)CC[...       LORACARBEF
# 299  COC(=O)[C@@H]1c2cc3c(c(O)c2[C@@H](O[C@@H]2O[C@...      NOGALAMYCIN
#
#                                                 smiles   hit_inh  \
# 0           COCc1ccc(s1)C(=O)N1CCC(CC1)(C(=O)O)n1cccn1  0.000018
# 1                 CCOC(=O)C1CCN(CC1)C(=S)NC(=O)c1cccs1  0.000004
# 2    CCN1CCCC1=O.CO[C@H]1CN(CCO)S(=O)(=O)c2ccccc21....  0.000002
# 3                                  ONC(=O)c1ccc(s1)C#C  0.000002
# 4                        CCNC(=S)NNC(=O)c1csc(c1)C(C)C  0.000002
# ..                                                 ...       ...
# 295   O=C(N1CCC[C@@H](C1)c1ccn[nH]1)c1ccc(cc1)Cn1cnnn1  0.000015
# 296                      COC(=O)c1sccc1NC(=S)N(C)CCC#N  0.000006
# 297  CCn1ncc(n1)NC(=O)c1ccc(s1)[C@H]1CCCN1Cc1[nH]cnc1C  0.000015
# 298                 O=C(Cc1ccccc1)NNC(=S)NC(=O)c1cccs1  0.000005
# 299  O=C1C=C(NC=N1)C1CCN(CC1)C(=O)c1ccc(s1)[C@H]1CCCO1  0.000010
#
#      hit_inh_epi_unc      hit_kill  hit_kill_epi_unc           Name  \
# 0       1.938463e-09  6.434774e-07      2.746465e-12  BRD-K52631221
# 1       1.784110e-10  6.488524e-07      3.357698e-12  BRD-K82870356
# 2       2.825133e-11  9.749020e-07      6.664941e-12  BRD-M17049327
# 3       4.871869e-11  9.844318e-07      1.142022e-11  BRD-K20971343
# 4       5.079206e-11  9.858252e-07      9.323063e-12  BRD-K29372009
# ..               ...           ...               ...            ...
# 295     2.008649e-09  3.221358e-06      6.639079e-11  BRD-A87246208
# 296     2.638478e-10  3.230704e-06      9.944416e-11  BRD-K21079502
# 297     1.592624e-09  3.232398e-06      5.600136e-11  BRD-A30288233
# 298     1.546700e-10  3.245806e-06      7.158436e-11  BRD-K91382924
# 299     4.239235e-10  3.250272e-06      7.213284e-11  BRD-A14178458
#
#      PROJECT_CODE      PROJECT_NAME  \
# 0            2001  General HTS Sets
# 1            2001  General HTS Sets
# 2            2001  General HTS Sets
# 3            2001  General HTS Sets
# 4            2001  General HTS Sets
# ..            ...               ...
# 295          2001  General HTS Sets
# 296          2001  General HTS Sets
# 297          7159      Calico PRISM
# 298          2001  General HTS Sets
# 299          7159      Calico PRISM
#
#                                               CXSMILES STEREO_COMMENTS  \
# 0           COCc1ccc(s1)C(=O)N1CCC(CC1)(C(O)=O)n1cccn1        as drawn
# 1                 CCOC(=O)C1CCN(CC1)C(=S)NC(=O)c1cccs1        as drawn
# 2    CCN1CCCC1=O.CC(C)c1nc(=O)cc(C)[nH]1.Fc1cccc(Cl...        as drawn
# 3                                  ONC(=O)c1ccc(s1)C#C        as drawn
# 4                        CCNC(=S)NNC(=O)c1csc(c1)C(C)C        as drawn
# ..                                                 ...             ...
# 295  O=C(N1CCC[C@@H](C1)c1ccn[nH]1)c1ccc(Cn2cnnn2)c...        as drawn
# 296                      COC(=O)c1sccc1NC(=S)N(C)CCC#N        as drawn
# 297  CCn1ncc(NC(=O)c2ccc(s2)[C@H]2CCCN2Cc2[nH]cnc2C...        as drawn
# 298                 O=C(Cc1ccccc1)NNC(=S)NC(=O)c1cccs1        as drawn
# 299  O=C(N1CCC(CC1)c1cc(=O)nc[nH]1)c1ccc(s1)[C@H]1C...        as drawn
#
#      row_num
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ..       ...
# 295      295
# 296      296
# 297      297
# 298      298
# 299      299
#
# [300 rows x 18 columns]
